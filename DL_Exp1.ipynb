# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaBongarde2004/Deep-Learning/blob/main/DL_Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical

np.random.seed(42)
tf.random.set_seed(42)

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
def create_mlp(initializer):
    model = Sequential()

    model.add(Dense(128, activation='relu',
                    kernel_initializer=initializer,
                    input_shape=(784,)))

    model.add(Dense(64, activation='relu',
                    kernel_initializer=initializer))

    model.add(Dense(10, activation='softmax',
                    kernel_initializer=initializer))

    return model

# %%
initializers = {
    "RandomNormal": tf.keras.initializers.RandomNormal(),
    "Xavier (GlorotUniform)": tf.keras.initializers.GlorotUniform(),
    "HeNormal": tf.keras.initializers.HeNormal()
}

history_init = {}

for name, init in initializers.items():
    print(f"\nTraining with {name} Initialization")

    model = create_mlp(init)

    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        X_train, y_train,
        epochs=10,
        batch_size=128,
        validation_data=(X_test, y_test),
        verbose=1
    )

    history_init[name] = history
# Out:
# Training with RandomNormal Initialization
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7800 - loss: 0.8127 - val_accuracy: 0.9390 - val_loss: 0.2032
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9463 - loss: 0.1883 - val_accuracy: 0.9587 - val_loss: 0.1346
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9627 - loss: 0.1278 - val_accuracy: 0.9675 - val_loss: 0.1061
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9723 - loss: 0.0958 - val_accuracy: 0.9715 - val_loss: 0.0928
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9781 - loss: 0.0748 - val_accuracy: 0.9740 - val_loss: 0.0841
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9832 - loss: 0.0596 - val_accuracy: 0.9745 - val_loss: 0.0811
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9865 - loss: 0.0475 - val_accuracy: 0.9756 - val_loss: 0.0793
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9895 - loss: 0.0384 - val_accuracy: 0.9759 - val_loss: 0.0795
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9917 - loss: 0.0315 - val_accuracy: 0.9755 - val_loss: 0.0824
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9934 - loss: 0.0261 - val_accuracy: 0.9745 - val_loss: 0.0863
#
# Training with Xavier (GlorotUniform) Initialization
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8258 - loss: 0.6251 - val_accuracy: 0.9513 - val_loss: 0.1644
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9567 - loss: 0.1513 - val_accuracy: 0.9639 - val_loss: 0.1187
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9709 - loss: 0.1010 - val_accuracy: 0.9690 - val_loss: 0.0987
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9796 - loss: 0.0743 - val_accuracy: 0.9712 - val_loss: 0.0909
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9845 - loss: 0.0570 - val_accuracy: 0.9715 - val_loss: 0.0912
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9876 - loss: 0.0454 - val_accuracy: 0.9724 - val_loss: 0.0906
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9903 - loss: 0.0366 - val_accuracy: 0.9726 - val_loss: 0.0898
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9921 - loss: 0.0296 - val_accuracy: 0.9724 - val_loss: 0.0931
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9941 - loss: 0.0232 - val_accuracy: 0.9711 - val_loss: 0.1032
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9950 - loss: 0.0192 - val_accuracy: 0.9691 - val_loss: 0.1096
#
# Training with HeNormal Initialization
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8346 - loss: 0.5784 - val_accuracy: 0.9544 - val_loss: 0.1540
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9588 - loss: 0.1449 - val_accuracy: 0.9658 - val_loss: 0.1117
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9724 - loss: 0.0976 - val_accuracy: 0.9712 - val_loss: 0.0940
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9794 - loss: 0.0712 - val_accuracy: 0.9724 - val_loss: 0.0880
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9843 - loss: 0.0544 - val_accuracy: 0.9740 - val_loss: 0.0868
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9883 - loss: 0.0417 - val_accuracy: 0.9749 - val_loss: 0.0878
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9910 - loss: 0.0331 - val_accuracy: 0.9740 - val_loss: 0.0893
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9934 - loss: 0.0260 - val_accuracy: 0.9739 - val_loss: 0.0937
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9943 - loss: 0.0210 - val_accuracy: 0.9725 - val_loss: 0.1003
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9949 - loss: 0.0177 - val_accuracy: 0.9714 - val_loss: 0.1112

# %%
optimizers = {
    "SGD": SGD(learning_rate=0.01),
    "Adam": Adam(learning_rate=0.001)
}

history_opt = {}

for name, opt in optimizers.items():
    print(f"\nTraining with {name} Optimizer")

    model = create_mlp(tf.keras.initializers.HeNormal())

    model.compile(
        optimizer=opt,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    history = model.fit(
        X_train, y_train,
        epochs=10,
        batch_size=128,
        validation_data=(X_test, y_test),
        verbose=1
    )

    history_opt[name] = history
# Out:
# Training with SGD Optimizer
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4979 - loss: 1.6486 - val_accuracy: 0.8595 - val_loss: 0.5453
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8673 - loss: 0.5065 - val_accuracy: 0.8958 - val_loss: 0.3808
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8958 - loss: 0.3809 - val_accuracy: 0.9102 - val_loss: 0.3264
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9061 - loss: 0.3323 - val_accuracy: 0.9173 - val_loss: 0.2963
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9149 - loss: 0.3033 - val_accuracy: 0.9236 - val_loss: 0.2754
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9206 - loss: 0.2823 - val_accuracy: 0.9266 - val_loss: 0.2597
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9249 - loss: 0.2657 - val_accuracy: 0.9299 - val_loss: 0.2467
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9293 - loss: 0.2518 - val_accuracy: 0.9324 - val_loss: 0.2357
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9327 - loss: 0.2399 - val_accuracy: 0.9352 - val_loss: 0.2261
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9345 - loss: 0.2293 - val_accuracy: 0.9373 - val_loss: 0.2175
#
# Training with Adam Optimizer
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8197 - loss: 0.5971 - val_accuracy: 0.9523 - val_loss: 0.1567
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9578 - loss: 0.1469 - val_accuracy: 0.9674 - val_loss: 0.1083
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9722 - loss: 0.0970 - val_accuracy: 0.9726 - val_loss: 0.0904
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9794 - loss: 0.0716 - val_accuracy: 0.9735 - val_loss: 0.0833
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9842 - loss: 0.0545 - val_accuracy: 0.9753 - val_loss: 0.0772
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9889 - loss: 0.0417 - val_accuracy: 0.9768 - val_loss: 0.0773
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9912 - loss: 0.0337 - val_accuracy: 0.9752 - val_loss: 0.0805
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9927 - loss: 0.0277 - val_accuracy: 0.9759 - val_loss: 0.0820
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9939 - loss: 0.0226 - val_accuracy: 0.9761 - val_loss: 0.0837
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9954 - loss: 0.0177 - val_accuracy: 0.9772 - val_loss: 0.0887

# %%
plt.figure(figsize=(10,5))
for name, history in history_init.items():
    plt.plot(history.history['loss'], label=name)
plt.title("Training Loss vs Epochs (Initialization Comparison)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
for name, history in history_init.items():
    plt.plot(history.history['accuracy'], label=name)
plt.title("Training Accuracy vs Epochs (Initialization Comparison)")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
for name, history in history_opt.items():
    plt.plot(history.history['loss'], label=name)
plt.title("Training Loss vs Epochs (Optimizer Comparison)")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
for name, history in history_opt.items():
    plt.plot(history.history['accuracy'], label=name)
plt.title("Training Accuracy vs Epochs (Optimizer Comparison)")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
